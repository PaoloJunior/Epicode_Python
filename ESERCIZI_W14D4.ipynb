# %%
import dotenv
import os
from sqlalchemy import create_engine
import pandas as pd
dotenv.load_dotenv(dotenv_path=".env", override=True)
username = os.getenv("username")
password = os.getenv("password")
host = os.getenv("host")
dbname = os.getenv("dbname")
conn_string = "mysql+pymysql://" + username + ":" + password + "@" + host + "/" + dbname
db_engine = create_engine(conn_string)
query= "SELECT * FROM dimproduct"
df=pd.read_sql(query,db_engine)

# %%
#dati totali
Totale=df.size
print("il numero di dati totali nel DataSet è:",Totale)
# Out:
# il numero di dati totali nel DataSet è: 21816

# %%
#metadati
print("L'elenco dei metadati è",df.columns)
# Out:
# L'elenco dei metadati è Index(['ProductKey', 'ProductAlternateKey', 'ProductSubcategoryKey',
#        'WeightUnitMeasureCode', 'SizeUnitMeasureCode', 'EnglishProductName',
#        'SpanishProductName', 'FrenchProductName', 'StandardCost',
#        'FinishedGoodsFlag', 'Color', 'SafetyStockLevel', 'ReorderPoint',
#        'ListPrice', 'Size', 'SizeRange', 'Weight', 'DaysToManufacture',
#        'ProductLine', 'DealerPrice', 'Class', 'Style', 'ModelName',
#        'LargePhoto', 'EnglishDescription', 'FrenchDescription',
#        'ChineseDescription', 'ArabicDescription', 'HebrewDescription',
#        'ThaiDescription', 'GermanDescription', 'JapaneseDescription',
#        'TurkishDescription', 'StartDate', 'EndDate', 'Status'],
#       dtype='object')

# %%
#prima riga
df.head(1)
# Out:
#    ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 0           1             AR-5381                    NaN
#
#   WeightUnitMeasureCode SizeUnitMeasureCode EnglishProductName  \
# 0                  None                None    Adjustable Race
#
#   SpanishProductName FrenchProductName  StandardCost  FinishedGoodsFlag  ...  \
# 0                                                NaN                  0  ...
#
#   ChineseDescription  ArabicDescription  HebrewDescription  ThaiDescription  \
# 0               None               None               None             None
#
#   GermanDescription JapaneseDescription  TurkishDescription  StartDate  \
# 0              None                None                None 2003-07-01
#
#   EndDate   Status
# 0     NaT  Current
#
# [1 rows x 36 columns]

# %%
#ultima riga
df.tail(1)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 605         606          BK-R19B-52                    2.0
#
#     WeightUnitMeasureCode SizeUnitMeasureCode  EnglishProductName  \
# 605                    LB                  CM  Road-750 Black, 52
#
#             SpanishProductName           FrenchProductName  StandardCost  \
# 605  Carretera: 750, negra, 52  Vélo de route 750 noir, 52        343.65
#
#      FinishedGoodsFlag  ...                 ChineseDescription  \
# 605                  1  ...  入门级成人自行车；确保越野旅行或公路骑乘的舒适。快拆式车毂和轮缘。
#
#                                      ArabicDescription  \
# 605  إنها دراجة مناسبة للمبتدئين من البالغين؛ فهي ت...
#
#                                      HebrewDescription  \
# 605  אופני מבוגרים למתחילים; מציעים רכיבה נוחה "מחו...
#
#                                        ThaiDescription  \
# 605  จักรยานระดับเริ่มต้นสำหรับผู้ใหญ่ ให้ความสบายใ...
#
#                                      GermanDescription  \
# ...

# %%
df.sample(5)
# Out:
#      ProductKey ProductAlternateKey  ProductSubcategoryKey  \
# 573         574          BK-T79U-50                    3.0
# 40           41             HJ-1428                    NaN
# 437         438          FR-R92B-62                   14.0
# 108         109             LJ-5161                    NaN
# 62           63             HN-3816                    NaN
#
#     WeightUnitMeasureCode SizeUnitMeasureCode         EnglishProductName  \
# 573                    LB                  CM      Touring-1000 Blue, 50
# 40                   None                None         Thin-Jam Hex Nut 2
# 437                    LB                  CM  HL Road Frame - Black, 62
# 108                  None                None        Thin-Jam Lock Nut 3
# 62                   None                None                 Hex Nut 12
#
#                     SpanishProductName                     FrenchProductName  \
# 573              Paseo: 1000, azul, 50       Vélo de randonnée 1000 bleu, 50
# 40
# ...

# %%
df["Color"].unique()
# Out:
# array(['NA', 'Black', 'Silver', 'Red', 'White', 'Blue', 'Multi', 'Yellow',
#        'Grey', 'Silver/Black'], dtype=object)

# %%
Pesante=df["Weight"].max()
print(Pesante)
# Out:
# 1050.0

# %%
Leggero=df["Weight"].min()
print(Leggero)
# Out:
# 2.12

# %%
Media=df["DealerPrice"].mean()
print(Media)
# Out:
# 448.5970597468353

# %%
filtro=(df["Weight"]<100000)
prodotti=df.loc[filtro,"ProductKey"]
prodotti_unici=prodotti.unique()
numero_prodotti=len(prodotti_unici)
print(numero_prodotti)
# Out:
# 282

# %%
prodotti_ordinati=df.sort_values(by="StandardCost", ascending=True)
numero_quarto=int(len(prodotti_ordinati)/4-1)
primo_quarto=prodotti_ordinati.iloc[0:numero_quarto]
max_quarto=primo_quarto["StandardCost"].max()
min_quarto=primo_quarto["StandardCost"].min()
print(min_quarto,max_quarto)
# Out:
# 0.86 144.59

# %%
filtro=df["Color"]=="Blue"
prodotti_blue=df.loc[filtro]
prezzomedio=prodotti_blue["StandardCost"].mean()
print(prezzomedio)
# Out:
# 527.5721428571429

# %%
df[["StandardCost","DealerPrice"]].tail(20)
# Out:
#      StandardCost  DealerPrice
# 586        419.78      461.694
# 587        419.78      461.694
# 588        419.78      461.694
# 589        419.78      461.694
# 590        308.22      338.994
# 591        308.22      338.994
# 592        308.22      338.994
# 593        308.22      338.994
# 594        308.22      338.994
# 595        294.58      323.994
# 596        294.58      323.994
# 597        294.58      323.994
# 598        294.58      323.994
# 599        294.58      323.994
# 600         23.97       32.394
# 601         44.95       60.744
# 602         53.94       72.894
# 603        343.65      323.994
# 604        343.65      323.994
# 605        343.65      323.994

# %%
filtro1=df["Color"].isin(["Black","Red"])
filtro2=(df["Color"]=="Black") | (df["Color"]=="Red")
prezzo_medio1=df.loc[filtro1,"StandardCost"].mean()
prezzo_medio2=df.loc[filtro2,"StandardCost"].mean()
print(prezzo_medio1)
print(prezzo_medio2)
# Out:
# 537.4548437500001
# 537.4548437500001

# %%
filtro=(df["Size"]=="42") & (df["Weight"]>10)
prodotti_filtrati=df.loc[filtro]
max_price=prodotti_filtrati["DealerPrice"].max()
print(max_price)
# Out:
# 2039.994

# %%
df=pd.read_csv(r"C:\Users\pagod\OneDrive\Desktop\Python\beginner_datasets\amazon.csv")

# %%
df.shape
# Out:
# (20000, 2)

# %%
df.sample(10)
# Out:
#                                               reviewText  Positive
# 3224   It really helps me keep track of my spending a...         1
# 17732  I hate puzzles...the little cardboard jigsaws ...         1
# 4249   This game is way to hard and it is boring afte...         0
# 18542  This game is a rip-off!!!!! All you do is pres...         0
# 17724  this is an awesome puzzle game. if you like pu...         1
# 19699  Great game! It works great on my Kindle Fire. ...         1
# 2804   this is an amazing app!  I bought it almost a ...         1
# 11134  This app does what it says. I use it with Pand...         1
# 580    You and your kids will love this game! Throwin...         1
# 13872  I was connected to my web folder within 3 minu...         1

# %%
df.columns
# Out:
# Index(['reviewText', 'Positive'], dtype='object')

# %%
positive1=df["Positive"]==1
negative0=df["Positive"]==0
positive=df.loc[positive1]
negative=df.loc[negative0]
numero_p=positive.count()
numero_n=negative.count()
rapporto=numero_p/numero_n
print("il numero di recensioni postitive è ",numero_p," il unmero di recensioni negative è ",numero_n," e il loro rapporto è ",rapporto)
# Out:
# il numero di recensioni postitive è  reviewText    15233
# Positive      15233
# dtype: int64  il unmero di recensioni negative è  reviewText    4767
# Positive      4767
# dtype: int64  e il loro rapporto è  reviewText    3.195511
# Positive      3.195511
# dtype: float64

# %%
df["Positive"].value_counts()
# Out:
# Positive
# 1    15233
# 0     4767
# Name: count, dtype: int64

# %%
df=pd.read_csv(r"C:\Users\pagod\OneDrive\Desktop\Python\beginner_datasets\diabetes.csv")
print(df.shape)
df.head(5)
# Out:
# (768, 9)
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
df.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# ...

# %%
filtro1=(df["Age (years)"]<20)
filtro2=(df["Age (years)"]>= 20) & (df["Age (years)"]<30)
filtro3=(df["Age (years)"]>=30) & (df["Age (years)"]<40)
filtro4=(df["Age (years)"]>=40) & (df["Age (years)"]<50)
filtro5=(df["Age (years)"]>50)
tab1=df.loc[filtro1]
tab2=df.loc[filtro2]
tab3=df.loc[filtro3]
tab4=df.loc[filtro4]
tab5=df.loc[filtro5]
media1=tab1["Diastolic blood pressure (mm Hg)"].mean()
media2=tab2["Diastolic blood pressure (mm Hg)"].mean()
media3=tab3["Diastolic blood pressure (mm Hg)"].mean()
media4=tab4["Diastolic blood pressure (mm Hg)"].mean()
media5=tab5["Diastolic blood pressure (mm Hg)"].mean()

print("La media per la prima fascia di età è:",media1)
print("La media per la seconda fascia di età è:",media2)
print("La media per la terza fascia di età è:",media3)
print("La media per la quarta fascia di età è:",media4)
print("La media per la quinta fascia di età è:",media5)
# Out:
# La media per la prima fascia di età è: nan
# La media per la seconda fascia di età è: 65.34848484848484
# La media per la terza fascia di età è: 69.66666666666667
# La media per la quarta fascia di età è: 73.94067796610169
# La media per la quinta fascia di età è: 78.38271604938272

# %%
df=pd.read_csv(r"C:\Users\pagod\OneDrive\Desktop\Python\beginner_datasets\insurance.csv")

# %%
print(df.shape)
print(df.head(10))
print(df.columns)
# Out:
# (1338, 7)
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
media_region=df.groupby("region")["charges"].mean()
print(media_region)
# Out:
# region
# northeast    13406.384516
# northwest    12417.575374
# southeast    14735.411438
# southwest    12346.937377
# Name: charges, dtype: float64

# %%
df["smoker"].value_counts()
filtro1=df["smoker"]=="yes"
filtro2=df["smoker"]=="no"
tab_fumatori=df.loc[filtro1]
tab_non_fumatori=df.loc[filtro2]
media_fumatori=tab_fumatori.groupby("smoker")["charges"].mean()
media_non_fumatori=tab_non_fumatori.groupby("smoker")["charges"].mean()
print("La media di spesa per i fumatori è:",media_fumatori)
print("La medi di spesa per i non fumatori è:",media_non_fumatori)
# Out:
# La media di spesa per i fumatori è: smoker
# yes    32050.231832
# Name: charges, dtype: float64
# La medi di spesa per i non fumatori è: smoker
# no    8434.268298
# Name: charges, dtype: float64

# %%
df["bmi"].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
valori_media=[]
vettore=df["bmi"].unique()
for valore in vettore:
    filtro=(df["bmi"]==valore)
    tab=df.loc[filtro]
    media=tab["charges"].mean()
    print(f"il valore medio per il percentile{valore} è: {media}")
# Out:
# il valore medio per il percentile27.9 è: 16884.924
# il valore medio per il percentile33.77 è: 1700.0923
# il valore medio per il percentile33.0 è: 6853.870486666667
# il valore medio per il percentile22.705 è: 12047.779170000002
# il valore medio per il percentile28.88 è: 8271.059949999999
# il valore medio per il percentile25.74 è: 7666.50485
# il valore medio per il percentile33.44 è: 8865.145349999999
# il valore medio per il percentile27.74 è: 13540.359933333333
# il valore medio per il percentile29.83 è: 14239.110866666664
# il valore medio per il percentile25.84 è: 14117.803264000002
# il valore medio per il percentile26.22 è: 8398.75705
# il valore medio per il percentile26.29 è: 27808.7251
# il valore medio per il percentile34.4 è: 11952.101
# il valore medio per il percentile39.82 è: 5840.112133333333
# il valore medio per il percentile42.13 è: 24162.47495
# il valore medio per il percentile24.6 è: 7954.34
# il valore medio per il percentile30.78 è: 21516.8756
# ...

# %%
df=pd.read_csv(r"C:\Users\pagod\OneDrive\Desktop\Python\beginner_datasets\pokemon.csv")

# %%
df.size
# Out:
# 10400

# %%
df.shape
# Out:
# (800, 13)

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df["#"].value_counts()
# Out:
# #
# 479    6
# 386    4
# 710    4
# 711    4
# 646    3
#       ..
# 250    1
# 251    1
# 252    1
# 253    1
# 721    1
# Name: count, Length: 721, dtype: int64

# %%
df.set_index("#")
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
filtro=df["Legendary"]==True
Leggendari=df.loc[filtro,"Name"]
Leggendari_unici=Leggendari.unique()
print(Leggendari_unici)
# Out:
# ['Articuno' 'Zapdos' 'Moltres' 'Mewtwo' 'MewtwoMega Mewtwo X'
#  'MewtwoMega Mewtwo Y' 'Raikou' 'Entei' 'Suicune' 'Lugia' 'Ho-oh'
#  'Regirock' 'Regice' 'Registeel' 'Latias' 'LatiasMega Latias' 'Latios'
#  'LatiosMega Latios' 'Kyogre' 'KyogrePrimal Kyogre' 'Groudon'
#  'GroudonPrimal Groudon' 'Rayquaza' 'RayquazaMega Rayquaza' 'Jirachi'
#  'DeoxysNormal Forme' 'DeoxysAttack Forme' 'DeoxysDefense Forme'
#  'DeoxysSpeed Forme' 'Uxie' 'Mesprit' 'Azelf' 'Dialga' 'Palkia' 'Heatran'
#  'Regigigas' 'GiratinaAltered Forme' 'GiratinaOrigin Forme' 'Darkrai'
#  'ShayminLand Forme' 'ShayminSky Forme' 'Arceus' 'Victini' 'Cobalion'
#  'Terrakion' 'Virizion' 'TornadusIncarnate Forme' 'TornadusTherian Forme'
#  'ThundurusIncarnate Forme' 'ThundurusTherian Forme' 'Reshiram' 'Zekrom'
#  'LandorusIncarnate Forme' 'LandorusTherian Forme' 'Kyurem'
#  'KyuremBlack Kyurem' 'KyuremWhite Kyurem' 'Xerneas' 'Yveltal'
#  'Zygarde50% Forme' 'Diancie' 'DiancieMega Diancie' 'HoopaHoopa Confined'
# ...

# %%
Filtro2=(df["Legendary"]==True) & (df["Type 1"]=="Grass")
Leggendari2=df.loc[Filtro2,"Name"]
Leggendari_unici2=Leggendari2.unique()
print(Leggendari_unici2)
# Out:
# ['ShayminLand Forme' 'ShayminSky Forme' 'Virizion']

# %%
Filtro3=(df["Legendary"]==True) & ((df["Type 1"]=="Fire") | (df["Type 1"]=="Ice"))
Leggendari3=df.loc[Filtro3,"Name"]
Leggendari_unici3=Leggendari3.unique()
print(Leggendari_unici3)
# Out:
# ['Articuno' 'Moltres' 'Entei' 'Ho-oh' 'Regice' 'Heatran' 'Volcanion']

# %%
tab_ordinata=df.sort_values(by="Name", ascending=True)
print(tab_ordinata)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 510  460                Abomasnow    Grass     Ice    494   90      92
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 68    63                     Abra  Psychic     NaN    310   25      20
# 392  359                    Absol     Dark     NaN    465   65     130
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# ..   ...                      ...      ...     ...    ...  ...     ...
# 632  571                  Zoroark     Dark     NaN    510   60     105
# 631  570                    Zorua     Dark     NaN    330   40      65
# 46    41                    Zubat   Poison  Flying    245   40      45
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
Filtro5=(df["HP"]<60) & (df["Attack"]>50)  & (df["Generation"]==1)
Leggendari5=df.loc[Filtro5,"Name"]
Leggendari_unici5=Leggendari5.unique()
print(Leggendari_unici5)
# Out:
# ['Charmander' 'Charmeleon' 'Wartortle' 'Rattata' 'Raticate' 'Spearow'
#  'Ekans' 'Pikachu' 'Sandshrew' 'Nidoran♂' 'Paras' 'Diglett' 'Dugtrio'
#  'Psyduck' 'Mankey' 'Growlithe' 'Bellsprout' 'Geodude' 'Graveler' 'Ponyta'
#  'Magneton' "Farfetch'd" 'Doduo' 'Shellder' 'Cloyster' 'Krabby' 'Kingler'
#  'Hitmonlee' 'Hitmonchan' 'Koffing' 'Seadra' 'Goldeen' 'Eevee' 'Kabuto'
#  'Dratini']
